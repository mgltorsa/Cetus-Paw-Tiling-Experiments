# %% [markdown]
# # Tiling experiments
# This paperwork will analyze data obtained from tiling experiments to compare 4 features of 4 different algorithms' implementations.
#
# The features or variables to measure are the following:
# - Algorithm speed up
# - Cache misses
# - Total of instructions executed
# - Cores rate usage
#
# The 4 algorithms selected for the experiment were:
# - Matrix multiplication
# - Vector multiplication
# - Jacobi Example
# - ? (still in process)
#
# For each algorithm will have 4 versions
# - Original implementation.
# - Tiled and handed parallelized algorithm from a benchmark.
# - Tiled and parallelized algorithm using Cetus.
# - Tiled, parallelized and loop interchange applied algorithm using Cetus.
#
# ## Methodology
#
# The proposed methodology is, we will have 4 different versions for each algorithm and will measure the features above for each of them. After that, we are going to use the data obtained to see if tiling improves the algorithms' performance.
#
# For each measurement the independent variable will be the amount ofcores to use for each experiment instance.

# %% [markdown]
# ## Data creation
# For obtaining/creating the data, we will use a group of tools to obtain data in runtime. Those tools are the following:
# - PAPI: To access hardware counters and to measure: Cache misses and total of instructions executed
# - OMP directives: To measure elapsed time for an algorithm execution and to measure speed up and cores rate usage.

# %% [markdown]
# ## Experiment results

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

default_tick_format_style = 'sci'
all_versions = ['parallel-non-tiled','parallel-paw-tiled', 'parallel-paw-single-tiled']

# %%
df = pd.read_csv("./experiments/results-v1.csv", names=['algorithm','version', 'cores', 'experiment', 'N','M','value'])
df
# Out:
#         algorithm                    version  cores    experiment     N     M  \
# 0     matrix-mult  parallel-paw-single-tiled      1  cache-misses  1200  1200
# 1     vector-mult         parallel-non-tiled      1  cache-misses  1200  1200
# 2          jacobi  parallel-paw-single-tiled      1  cache-misses  1200  1200
# 3     matrix-mult         parallel-non-tiled      1  cache-misses  1200  1200
# 4     vector-mult  parallel-paw-single-tiled      1  cache-misses  1200  1200
# ...           ...                        ...    ...           ...   ...   ...
# 2155  vector-mult  parallel-paw-single-tiled      8      speed-up  1200  1200
# 2156       jacobi         parallel-non-tiled      8      speed-up  1200  1200
# 2157  matrix-mult         parallel-paw-tiled      8      speed-up  1200  1200
# 2158  vector-mult         parallel-paw-tiled      8      speed-up  1200  1200
# 2159       jacobi  parallel-paw-single-tiled      8      speed-up  1200  1200
#
#              value
# 0     5.020990e+06
# 1     1.416000e+05
# 2     3.095400e+05
# 3     4.130593e+06
# 4     1.563620e+05
# ...            ...
# 2155  1.108000e-03
# 2156  3.151000e-03
# 2157  1.803476e+00
# 2158  1.129000e-03
# 2159  2.968000e-03
#
# [2160 rows x 7 columns]

# %%
pp = pd.read_csv("./experiments/test.csv", names=['algorithm','version', 'cores', 'experiment', 'N','M','value'])
pp
# Out:
#      algorithm             version  cores    experiment     N     M  value
# 0  matrix-mult  parallel-non-tiled      5  cache-misses  1200  1200      5
# 1  matrix-mult  parallel-non-tiled      5  cache-misses  1200  1200      7
# 2  matrix-mult  parallel-non-tiled      5       total-i  1200  1200      1
# 3  matrix-mult  parallel-non-tiled      5       total-i  1200  1200      3
# 4  matrix-mult  parallel-non-tiled      4  cache-misses  1200  1200      2

# %%
def group_by(dataframe, groups=['algorithm', "version", "cores", "experiment"]):
    return dataframe.groupby(groups, as_index=False)

# %%
def group_min(dataframe):
    ss = group_by(dataframe, ['algorithm', "version", "cores", "experiment"])
    return ss.min()

group_min(pp)
group_by(pp).std()
# Out:
#      algorithm             version  cores    experiment    N    M     value
# 0  matrix-mult  parallel-non-tiled      4  cache-misses  NaN  NaN       NaN
# 1  matrix-mult  parallel-non-tiled      5  cache-misses  0.0  0.0  1.414214
# 2  matrix-mult  parallel-non-tiled      5       total-i  0.0  0.0  1.414214

# %%
def group_mean(dataframe):
    ss = group_by(dataframe, ['algorithm', "version", "cores", "experiment"])
    return ss.mean()

group_mean(pp)
# Out:
#      algorithm             version  cores    experiment       N       M  value
# 0  matrix-mult  parallel-non-tiled      4  cache-misses  1200.0  1200.0    2.0
# 1  matrix-mult  parallel-non-tiled      5  cache-misses  1200.0  1200.0    6.0
# 2  matrix-mult  parallel-non-tiled      5       total-i  1200.0  1200.0    2.0

# %%
def filter_by_experiment(algorithm, experiment)->pd.DataFrame:
    filteredAlgorithms = df.loc[(df['algorithm']==algorithm)]
    filteredRows = filteredAlgorithms.loc[df['experiment']==experiment]
    return filteredRows

filter_by_experiment('matrix-mult', 'speed-up').head()
# Out:
#         algorithm                    version  cores experiment     N     M  \
# 1440  matrix-mult  parallel-paw-single-tiled      1   speed-up  1200  1200
# 1443  matrix-mult         parallel-non-tiled      1   speed-up  1200  1200
# 1446  matrix-mult         parallel-paw-tiled      1   speed-up  1200  1200
# 1449  matrix-mult  parallel-paw-single-tiled      2   speed-up  1200  1200
# 1452  matrix-mult         parallel-non-tiled      2   speed-up  1200  1200
#
#          value
# 1440  7.234352
# 1443  7.958315
# 1446  8.762267
# 1449  3.878527
# 1452  4.329642

# %%
def get_unique(dataframe: pd.DataFrame, name):
    return dataframe[name].unique()

get_unique(df, 'version')
# Out:
# array(['parallel-paw-single-tiled', 'parallel-non-tiled',
#        'parallel-paw-tiled'], dtype=object)

# %%
def get_experimental_values(dataframe: pd.DataFrame, versions=[])->dict:
    if(len(versions) == 0):
        versions=get_unique(dataframe, 'version')
    dictionary={}
    for version in versions:
        dataframe_by_versions = dataframe.loc[dataframe['version']==version]
        x = dataframe_by_versions['cores']
        y = dataframe_by_versions['value']
        dictionary[version] = {'x': x, 'y':y}
    return dictionary
matrix_mult_speed_df = filter_by_experiment('matrix-mult','speed-up')
experiment = get_experimental_values(matrix_mult_speed_df)
experiment.keys()
# Out:
# dict_keys(['parallel-paw-single-tiled', 'parallel-non-tiled', 'parallel-paw-tiled'])

# %%
matrix_mult_speed_df = filter_by_experiment('matrix-mult','speed-up')
experiment = get_experimental_values(matrix_mult_speed_df, ['parallel-paw-single-tiled','parallel-non-tiled'])
experiment.keys()
# Out:
# dict_keys(['parallel-paw-single-tiled', 'parallel-non-tiled'])

# %%
def get_plottable_experiment(experiment: dict)->dict:
    colors = ['b','g','r','c','m','y','k']
    colors.reverse()
    dictionary = {}
    for version in experiment:
        x=experiment[version]['x']
        y=experiment[version]['y']
        dictionary[version]={'x':x, 'y':y ,'color':colors.pop()}
    return dictionary

matrix_mult_speed_df = filter_by_experiment('matrix-mult','speed-up')
experiment = get_experimental_values(matrix_mult_speed_df)
plottable_experiment = get_plottable_experiment(experiment)
plottable_experiment['parallel-non-tiled']['x'].head()
# Out:
# 1443    1
# 1452    2
# 1461    3
# 1470    4
# 1479    5
# Name: cores, dtype: int64

# %%
def plot_scatter(experiment, versions=all_versions,tick_format_style=default_tick_format_style ):
    
    fig=plt.figure(figsize=(25, 8))
        
    gg=0
    min_y = 0
    max_y = 0
    
    
    for version in versions:
        canva = fig.add_subplot(131+gg)
        gg+=1
        canva.title.set_text(version)
        x = exp[version]['x']
        y = exp[version]['y']
        
        max_y = max(max_y, y.max())
        min_y = min(min_y, y.min())
        
        #plt.ylim([min_y, max_y])

        c = exp[version]
        plt.plot(x, y, 'o')
        m, b = np.polyfit(x, y, 1)

        plt.ticklabel_format(style=tick_format_style, axis='y', scilimits=(0,0))
        plt.plot(x, m*x+b)
    

    plt.show()

# %%
fdf = filter_by_experiment('matrix-mult', 'total-instructions')
exp = get_experimental_values(fdf)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp)

# %%
def plot_lines(dataframe: pd.DataFrame, versions=[], canva=None, title="", tick_format_style=default_tick_format_style):
    
    if(canva==None):
        fig=plt.figure(figsize=(20, 10))
        canva = fig.add_subplot()
        
    
    canva.title.set_text(title)

    plt.ylabel('Values')
    plt.xlabel('# Cores')
    
    
    aux_experiment = get_experimental_values(dataframe,versions)
    experiment = get_plottable_experiment(aux_experiment)
    
       
    x_min=0
    x_max=10
    
    y_min=0
    y_max=10
    
    plt.ticklabel_format(style=tick_format_style, axis='y', scilimits=(0,0))
 
    
    # lines
    for version in experiment.keys():
        color = experiment[version]['color']
        x = experiment[version]['x']
        x_min = x.min()
        x_max = x.max()
        
        y = experiment[version]['y']
        y_min= y.min()
        y_max= y.max()
    
        line, = plt.plot(x, y, color)
        line.set_label(version)
        
    # axh lines
    for version in experiment.keys():
        color = experiment[version]['color']
        y = experiment[version]['y']
        plt.axhline(y=y.min(), color=color, linestyle=":", label='min-'+version)
        plt.legend()
    
#     x_min=x_min-x_min*0.05
#     x_max=x_max+x_max*0.05
    
#     y_min=y_min-y_min*0.1    
#     y_max=y_max+y_max*0.1
    
#     x_lim=[x_min, x_max]
#     y_lim=[y_min, y_max]
    
#     print(str(x_lim))
#     print(str(y_lim))
#     plt.xlim(x_lim)
#     plt.ylim(y_lim)

# %%
def plot_bars(dataframe: pd.DataFrame, versions=[], canva=None, tick_format_style=default_tick_format_style):
    
    if(canva==None):
        fig=plt.figure(figsize=(20, 10))
        canva = fig.add_subplot()
    
    # bars
    aux_experiment = get_experimental_values(dataframe,versions)
    experiment = get_plottable_experiment(aux_experiment)
    experiment_keys = list(experiment.keys())
    min_execution_time_version = experiment_keys[0]
    min_execution_time = experiment[min_execution_time_version]['y'].min()
    for version in experiment_keys:
        cur_experiment_time = experiment[version]['y'].min()
        if min_execution_time > cur_experiment_time:
            min_execution_time = cur_experiment_time
            min_execution_time_version = version
        
    version_filtered_df = dataframe.loc[dataframe['version'] == min_execution_time_version]
    cores_df = version_filtered_df.loc[dataframe['value'] == min_execution_time]
    cores_with_min_execution_time = cores_df['cores'].values[0]
    bars_df = dataframe.loc[dataframe['cores']==cores_with_min_execution_time] 
        

    names=[]
    colors=[]
    values=[]
    for version in experiment_keys:
        names.append(version)
        
        val = bars_df.loc[bars_df['version']==version]['value'].values[0]
        values.append(val)
        
        color = experiment[version]['color']
        colors.append(color)


    plt.ticklabel_format(style=tick_format_style, axis='y', scilimits=(0,0))
    
    canva.title.set_text('Bar chart - Cores: '+str(cores_with_min_execution_time))
    
    
    plt.bar(names, values, color=colors)
    
    plt.ylabel('Values')
    plt.xlabel('Versions')

# %%
def plot_experiments(experiment_label, dataframe: pd.DataFrame, versions=[], tick_format_style=default_tick_format_style):
    
    fig=plt.figure(figsize=(25, 10))
    
        
    plt.suptitle(experiment_label+' analysis')
    
    canva = fig.add_subplot(121)
    plot_lines(dataframe, versions, canva, tick_format_style=tick_format_style)
    
    canva2 = fig.add_subplot(122)
    plot_bars(dataframe, versions, canva2, tick_format_style=tick_format_style)
    
    plt.show()
    
matrix_mult_speed_df = filter_by_experiment('matrix-mult','cache-misses')
plot_experiments('matrix-mult', group_mean(matrix_mult_speed_df))

# %%
def plot_bars_group(dataframe: pd.DataFrame, experiments=[]):
    if(len(experiments) == 0):
        experiments=get_unique(dataframe, 'experiment')
    
    return experiments

plot_bars_group(df)
# Out:
# array(['cache-misses', 'total-instructions', 'speed-up'], dtype=object)

# %% [markdown]
# # Matrix multiplication

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Cache misses
#
# Now, we are going to analyze the cache misses for the **matrix multiplication** algorithm.

# %%
df_mm_cache = filter_by_experiment('matrix-mult','cache-misses')
exp = get_experimental_values(df_mm_cache)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='sci')

# %%
df_std_mm_cache = group_by(df_mm_cache)
df_std_mm_cache = df_std_mm_cache.std()
df_std_mm_cache
# Out:
#       algorithm                    version  cores    experiment    N    M  \
# 0   matrix-mult         parallel-non-tiled      1  cache-misses  0.0  0.0
# 1   matrix-mult         parallel-non-tiled      2  cache-misses  0.0  0.0
# 2   matrix-mult         parallel-non-tiled      3  cache-misses  0.0  0.0
# 3   matrix-mult         parallel-non-tiled      4  cache-misses  0.0  0.0
# 4   matrix-mult         parallel-non-tiled      5  cache-misses  0.0  0.0
# 5   matrix-mult         parallel-non-tiled      6  cache-misses  0.0  0.0
# 6   matrix-mult         parallel-non-tiled      7  cache-misses  0.0  0.0
# 7   matrix-mult         parallel-non-tiled      8  cache-misses  0.0  0.0
# 8   matrix-mult  parallel-paw-single-tiled      1  cache-misses  0.0  0.0
# 9   matrix-mult  parallel-paw-single-tiled      2  cache-misses  0.0  0.0
# 10  matrix-mult  parallel-paw-single-tiled      3  cache-misses  0.0  0.0
# 11  matrix-mult  parallel-paw-single-tiled      4  cache-misses  0.0  0.0
# 12  matrix-mult  parallel-paw-single-tiled      5  cache-misses  0.0  0.0
# 13  matrix-mult  parallel-paw-single-tiled      6  cache-misses  0.0  0.0
# 14  matrix-mult  parallel-paw-single-tiled      7  cache-misses  0.0  0.0
# 15  matrix-mult  parallel-paw-single-tiled      8  cache-misses  0.0  0.0
# 16  matrix-mult         parallel-paw-tiled      1  cache-misses  0.0  0.0
# 17  matrix-mult         parallel-paw-tiled      2  cache-misses  0.0  0.0
# 18  matrix-mult         parallel-paw-tiled      3  cache-misses  0.0  0.0
# 19  matrix-mult         parallel-paw-tiled      4  cache-misses  0.0  0.0
# 20  matrix-mult         parallel-paw-tiled      5  cache-misses  0.0  0.0
# 21  matrix-mult         parallel-paw-tiled      6  cache-misses  0.0  0.0
# 22  matrix-mult         parallel-paw-tiled      7  cache-misses  0.0  0.0
# 23  matrix-mult         parallel-paw-tiled      8  cache-misses  0.0  0.0
#
#            value
# 0   1.856672e+06
# 1   9.825193e+05
# 2   6.922923e+05
# 3   3.597075e+05
# 4   3.562515e+05
# 5   1.000733e+05
# 6   1.102793e+05
# 7   7.939689e+04
# 8   3.638300e+05
# 9   3.449999e+05
# 10  8.108164e+05
# 11  6.644354e+05
# 12  2.542749e+05
# 13  2.302570e+05
# 14  1.953728e+05
# 15  2.671908e+04
# 16  1.696378e+06
# 17  9.500884e+05
# 18  6.985886e+05
# 19  1.875441e+05
# 20  1.973980e+05
# 21  1.044696e+05
# 22  8.943023e+04
# 23  7.425762e+04

# %%
exp = get_experimental_values(df_std_mm_cache)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='sci')

# %%
plot_experiments('Matrix Mult - Cache misses',group_mean(df_mm_cache))

# %% [markdown]
# ### Total of instructions executed

# %%
df_mm_ti = filter_by_experiment('matrix-mult','total-instructions')
df_mm_ti
# Out:
#         algorithm                    version  cores          experiment     N  \
# 72    matrix-mult         parallel-non-tiled      1  total-instructions  1200
# 73    matrix-mult         parallel-paw-tiled      1  total-instructions  1200
# 74    matrix-mult  parallel-paw-single-tiled      1  total-instructions  1200
# 81    matrix-mult         parallel-non-tiled      2  total-instructions  1200
# 82    matrix-mult         parallel-paw-tiled      2  total-instructions  1200
# ...           ...                        ...    ...                 ...   ...
# 1423  matrix-mult         parallel-paw-tiled      7  total-instructions  1200
# 1424  matrix-mult  parallel-paw-single-tiled      7  total-instructions  1200
# 1431  matrix-mult         parallel-non-tiled      8  total-instructions  1200
# 1432  matrix-mult         parallel-paw-tiled      8  total-instructions  1200
# 1433  matrix-mult  parallel-paw-single-tiled      8  total-instructions  1200
#
#          M         value
# 72    1200  8.814241e+10
# 73    1200  9.843843e+10
# 74    1200  8.227594e+10
# 81    1200  4.407122e+10
# 82    1200  4.919043e+10
# ...    ...           ...
# 1423  1200  1.406561e+10
# 1424  1200  1.234351e+10
# 1431  1200  1.101782e+10
# 1432  1200  1.225443e+10
# 1433  1200  1.028661e+10
#
# [240 rows x 7 columns]

# %%
exp = get_experimental_values(df_mm_ti)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='sci')

# %%
plot_experiments('Matrix Mult - Total instructions executed',group_mean(df_mm_ti))

# %% [markdown]
# ### Execution time

# %% [markdown]
# First we are going to take a look at the scattered behaviour of the execution times took from matrix multiplication's experiments.

# %%
df_mm_ex = filter_by_experiment('matrix-mult','speed-up')
df_mm_ex
# Out:
#         algorithm                    version  cores experiment     N     M  \
# 1440  matrix-mult  parallel-paw-single-tiled      1   speed-up  1200  1200
# 1443  matrix-mult         parallel-non-tiled      1   speed-up  1200  1200
# 1446  matrix-mult         parallel-paw-tiled      1   speed-up  1200  1200
# 1449  matrix-mult  parallel-paw-single-tiled      2   speed-up  1200  1200
# 1452  matrix-mult         parallel-non-tiled      2   speed-up  1200  1200
# ...           ...                        ...    ...        ...   ...   ...
# 2145  matrix-mult         parallel-non-tiled      7   speed-up  1200  1200
# 2148  matrix-mult         parallel-paw-tiled      7   speed-up  1200  1200
# 2151  matrix-mult  parallel-paw-single-tiled      8   speed-up  1200  1200
# 2154  matrix-mult         parallel-non-tiled      8   speed-up  1200  1200
# 2157  matrix-mult         parallel-paw-tiled      8   speed-up  1200  1200
#
#          value
# 1440  7.234352
# 1443  7.958315
# 1446  8.762267
# 1449  3.878527
# 1452  4.329642
# ...        ...
# 2145  2.319680
# 2148  1.945985
# 2151  2.162116
# 2154  2.231018
# 2157  1.803476
#
# [240 rows x 7 columns]

# %%
exp = get_experimental_values(df_mm_ex)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='sci')

# %%
plot_experiments('Matrix Mult - Execution time',group_mean(df_mm_ex))

# %% [markdown]
# #### Observations
# Unexpectedly, the **paw tiled** *(multi tiling)* version got the best performance and the the **single tiled** version got the worst performance. Due to these observations, one can suppose the following:
# - paw single tiled version is not splitting the data in the best possible way, so the cache misses get increased and then the performance get decreased.
# - In contrast, paw tiled version (multi-tiled version) is splitting the data in a better way and performance and cache hits get increased.

# %% [markdown]
# # Matrix-vector multiplication

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Cache misses

# %%
df_vm_cache = filter_by_experiment('vector-mult','cache-misses')
df_vm_cache
# Out:
#         algorithm                    version  cores    experiment     N     M  \
# 1     vector-mult         parallel-non-tiled      1  cache-misses  1200  1200
# 4     vector-mult  parallel-paw-single-tiled      1  cache-misses  1200  1200
# 7     vector-mult         parallel-paw-tiled      1  cache-misses  1200  1200
# 10    vector-mult         parallel-non-tiled      2  cache-misses  1200  1200
# 13    vector-mult  parallel-paw-single-tiled      2  cache-misses  1200  1200
# ...           ...                        ...    ...           ...   ...   ...
# 1354  vector-mult  parallel-paw-single-tiled      7  cache-misses  1200  1200
# 1357  vector-mult         parallel-paw-tiled      7  cache-misses  1200  1200
# 1360  vector-mult         parallel-non-tiled      8  cache-misses  1200  1200
# 1363  vector-mult  parallel-paw-single-tiled      8  cache-misses  1200  1200
# 1366  vector-mult         parallel-paw-tiled      8  cache-misses  1200  1200
#
#          value
# 1     141600.0
# 4     156362.0
# 7     144033.0
# 10     73158.0
# 13     67270.0
# ...        ...
# 1354   14453.0
# 1357   37097.0
# 1360   18934.0
# 1363   12705.0
# 1366   32269.0
#
# [240 rows x 7 columns]

# %%
exp = get_experimental_values(df_vm_cache)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='sci')

# %%
plot_experiments('Matrix-vector Mult - Cache misses',group_mean(df_vm_cache))

# %% [markdown]
# ### Total of instructions executed

# %%
df_vm_ti = filter_by_experiment('vector-mult','total-instructions')
df_vm_ti
# Out:
#         algorithm                    version  cores          experiment     N  \
# 75    vector-mult         parallel-non-tiled      1  total-instructions  1200
# 76    vector-mult         parallel-paw-tiled      1  total-instructions  1200
# 77    vector-mult  parallel-paw-single-tiled      1  total-instructions  1200
# 84    vector-mult         parallel-non-tiled      2  total-instructions  1200
# 85    vector-mult         parallel-paw-tiled      2  total-instructions  1200
# ...           ...                        ...    ...                 ...   ...
# 1426  vector-mult         parallel-paw-tiled      7  total-instructions  1200
# 1427  vector-mult  parallel-paw-single-tiled      7  total-instructions  1200
# 1434  vector-mult         parallel-non-tiled      8  total-instructions  1200
# 1435  vector-mult         parallel-paw-tiled      8  total-instructions  1200
# 1436  vector-mult  parallel-paw-single-tiled      8  total-instructions  1200
#
#          M       value
# 75    1200  50412036.0
# 76    1200  59011261.0
# 77    1200  56635780.0
# 84    1200  25220016.0
# 85    1200  29502655.0
# ...    ...         ...
# 1426  1200   8455950.0
# 1427  1200   8208444.0
# 1434  1200   6323148.0
# 1435  1200   7374027.0
# 1436  1200   7177750.0
#
# [240 rows x 7 columns]

# %%
exp = get_experimental_values(df_vm_ti)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='sci')

# %%
plot_experiments('Matrix-vector Mult - Total instructions executed',group_mean(df_vm_ti))

# %% [markdown]
# ### Execution time

# %%
df_vm_ex = filter_by_experiment('vector-mult','speed-up')
df_vm_ex
# Out:
#         algorithm                    version  cores experiment     N     M  \
# 1441  vector-mult         parallel-non-tiled      1   speed-up  1200  1200
# 1444  vector-mult  parallel-paw-single-tiled      1   speed-up  1200  1200
# 1447  vector-mult         parallel-paw-tiled      1   speed-up  1200  1200
# 1450  vector-mult         parallel-non-tiled      2   speed-up  1200  1200
# 1453  vector-mult  parallel-paw-single-tiled      2   speed-up  1200  1200
# ...           ...                        ...    ...        ...   ...   ...
# 2146  vector-mult  parallel-paw-single-tiled      7   speed-up  1200  1200
# 2149  vector-mult         parallel-paw-tiled      7   speed-up  1200  1200
# 2152  vector-mult         parallel-non-tiled      8   speed-up  1200  1200
# 2155  vector-mult  parallel-paw-single-tiled      8   speed-up  1200  1200
# 2158  vector-mult         parallel-paw-tiled      8   speed-up  1200  1200
#
#          value
# 1441  0.003296
# 1444  0.004414
# 1447  0.003718
# 1450  0.001778
# 1453  0.002555
# ...        ...
# 2146  0.001269
# 2149  0.001257
# 2152  0.000983
# 2155  0.001108
# 2158  0.001129
#
# [240 rows x 7 columns]

# %%
exp = get_experimental_values(df_vm_ex)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='sci')

# %%
plot_experiments('Matrix-vector Mult - Execution time',group_mean(df_vm_ex))

# %% [markdown]
# # Jacobi

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Cache misses

# %%
df_jb_cache = filter_by_experiment('jacobi','cache-misses')
df_jb_cache
# Out:
#      algorithm                    version  cores    experiment     N     M  \
# 2       jacobi  parallel-paw-single-tiled      1  cache-misses  1200  1200
# 5       jacobi         parallel-paw-tiled      1  cache-misses  1200  1200
# 8       jacobi         parallel-non-tiled      1  cache-misses  1200  1200
# 11      jacobi  parallel-paw-single-tiled      2  cache-misses  1200  1200
# 14      jacobi         parallel-paw-tiled      2  cache-misses  1200  1200
# ...        ...                        ...    ...           ...   ...   ...
# 1355    jacobi         parallel-paw-tiled      7  cache-misses  1200  1200
# 1358    jacobi         parallel-non-tiled      7  cache-misses  1200  1200
# 1361    jacobi  parallel-paw-single-tiled      8  cache-misses  1200  1200
# 1364    jacobi         parallel-paw-tiled      8  cache-misses  1200  1200
# 1367    jacobi         parallel-non-tiled      8  cache-misses  1200  1200
#
#          value
# 2     309540.0
# 5     321206.0
# 8     328181.0
# 11    155588.0
# 14    333535.0
# ...        ...
# 1355  318298.0
# 1358   40641.0
# 1361   35674.0
# 1364  283531.0
# 1367   33630.0
#
# [240 rows x 7 columns]

# %%
exp = get_experimental_values(df_jb_cache)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='sci')

# %%
plot_experiments('Jacobi - Cache misses',group_mean(df_jb_cache))

# %% [markdown]
# ### Total of instructions executed

# %%
df_jb_ti = filter_by_experiment('jacobi','total-instructions')
df_jb_ti
# Out:
#      algorithm                    version  cores          experiment     N  \
# 78      jacobi         parallel-non-tiled      1  total-instructions  1200
# 79      jacobi         parallel-paw-tiled      1  total-instructions  1200
# 80      jacobi  parallel-paw-single-tiled      1  total-instructions  1200
# 87      jacobi         parallel-non-tiled      2  total-instructions  1200
# 88      jacobi         parallel-paw-tiled      2  total-instructions  1200
# ...        ...                        ...    ...                 ...   ...
# 1429    jacobi         parallel-paw-tiled      7  total-instructions  1200
# 1430    jacobi  parallel-paw-single-tiled      7  total-instructions  1200
# 1437    jacobi         parallel-non-tiled      8  total-instructions  1200
# 1438    jacobi         parallel-paw-tiled      8  total-instructions  1200
# 1439    jacobi  parallel-paw-single-tiled      8  total-instructions  1200
#
#          M        value
# 78    1200  122005548.0
# 79    1200  130636001.0
# 80    1200  113971637.0
# 87    1200   61104348.0
# 88    1200  130642842.0
# ...    ...          ...
# 1429  1200  130647384.0
# 1430  1200   17125867.0
# 1437  1200   15292683.0
# 1438  1200  130648780.0
# 1439  1200   14276771.0
#
# [240 rows x 7 columns]

# %%
exp = get_experimental_values(df_jb_ti)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='plain')

# %%
df_jb_ti[(df_jb_ti.version=='parallel-paw-tiled' )& (df_jb_ti.cores==2)]
# Out:
#      algorithm             version  cores          experiment     N     M  \
# 88      jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
# 232     jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
# 376     jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
# 520     jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
# 664     jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
# 808     jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
# 952     jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
# 1096    jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
# 1240    jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
# 1384    jacobi  parallel-paw-tiled      2  total-instructions  1200  1200
#
#             value
# 88    130642842.0
# 232   130642106.0
# 376   130643849.0
# 520   130642835.0
# 664   130642651.0
# 808   130643023.0
# 952   130642681.0
# 1096  130642778.0
# 1240  130643303.0
# 1384  130642554.0

# %%
plot_experiments('Jacobi - Total instructions executed',group_mean(df_jb_ti))

# %% [markdown]
# ### Execution time

# %%
df_jb_ex = filter_by_experiment('jacobi','speed-up')
df_jb_ex
# Out:
#      algorithm                    version  cores experiment     N     M  \
# 1442    jacobi         parallel-paw-tiled      1   speed-up  1200  1200
# 1445    jacobi         parallel-non-tiled      1   speed-up  1200  1200
# 1448    jacobi  parallel-paw-single-tiled      1   speed-up  1200  1200
# 1451    jacobi         parallel-paw-tiled      2   speed-up  1200  1200
# 1454    jacobi         parallel-non-tiled      2   speed-up  1200  1200
# ...        ...                        ...    ...        ...   ...   ...
# 2147    jacobi         parallel-non-tiled      7   speed-up  1200  1200
# 2150    jacobi  parallel-paw-single-tiled      7   speed-up  1200  1200
# 2153    jacobi         parallel-paw-tiled      8   speed-up  1200  1200
# 2156    jacobi         parallel-non-tiled      8   speed-up  1200  1200
# 2159    jacobi  parallel-paw-single-tiled      8   speed-up  1200  1200
#
#          value
# 1442  0.011861
# 1445  0.011506
# 1448  0.010709
# 1451  0.005887
# 1454  0.006296
# ...        ...
# 2147  0.003569
# 2150  0.003447
# 2153  0.005118
# 2156  0.003151
# 2159  0.002968
#
# [240 rows x 7 columns]

# %%
exp = get_experimental_values(df_jb_ex)
plot_exp = get_plottable_experiment(exp)
plot_scatter(plot_exp, tick_format_style='sci')

# %%
plot_experiments('Jacobi - Execution time',group_mean(df_jb_ex))

# %% [markdown]
# # Conclusions
#
# - It looks like the effectivity is context-based.  For example, we could see some improvement over the cache hits and performance in the **matrix** and **vector-matrix** multiplication algorithms but it not the same case for the **jacobi** algorithm.
